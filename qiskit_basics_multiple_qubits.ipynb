# %% [markdown]
# <a href="https://colab.research.google.com/github/yellomello/Qiskit_Basics/blob/main/qiskit_basics_multiple_qubits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit-aer

# %%
# !pip install qiskit

# %%
import qiskit
print(qiskit.__version__)
# Out:
# 0.25.1

# %%
from qiskit import *
from qiskit.tools.visualization import plot_histogram, array_to_latex, plot_bloch_multivector
# %matplotlib inline

# %%
# qr = QuantumRegister(2) #stores 1 qubit
# cr = ClassicalRegister(2) #stores 1 classical bit

circuit = QuantumCircuit(2)
circuit.h(0) #Runs through a Hadamard gate
circuit.measure_all() #this creates a python object of a circuit

# %%
simulator = Aer.get_backend('qasm_simulator')
result = execute(circuit, backend= simulator ).result()
# count=result.get_counts()
plot_histogram(result.get_counts())
# array_to_latex(statevector)

# %%
plot_bloch_multivector(statevector)

# %%
a= result.get_counts()

# %%
a
# Out:
# {'00': 0.5, '01': 0.5}
